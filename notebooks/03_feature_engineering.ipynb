# %% [markdown]
# # Part III: Feature Engineering

# %% [markdown]
# ## Basic settings

# %%
import os
os.environ["PYTHONUTF8"] = "1"

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import warnings
from datetime import datetime, timedelta

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")
pd.options.display.max_rows = 50
pd.options.display.max_columns = None

# %%
src_path = os.path.abspath(os.path.join("..", "src"))
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
from utils.utils import save_data

# %%
DATA_DIR = "../data"

# %% [markdown]
# ## Load preprocessed data

# %%
df_sales = pd.read_csv(
    os.path.join(DATA_DIR, "sales_data_preprocessed.csv"), parse_dates=["date"]
)
df_weather = pd.read_csv(
    os.path.join(DATA_DIR, "weather_preprocessed.csv"), parse_dates=["date"]
)

# %% [markdown]
# ## Feature Engineering

# %%
# Start by creating a copy of the sales dataframe
df_features = df_sales.copy()

# %% [markdown]
# ### Separating train and test

# %%
# Test set will be the last 3 months of 2017 (Oct, Nov, Dec 2017)
cutoff_date = pd.Timestamp("2017-10-01")
print(f"Train-test split date: {cutoff_date}")

# Create a flag for train/test split
df_features["is_test"] = df_features["date"] >= cutoff_date
print(f"Training df_features: {len(df_features[~df_features['is_test']])} rows")
print(f"Test df_features: {len(df_features[df_features['is_test']])} rows")

# Merge weather df_features
df_features = pd.merge(
    df_features,
    df_weather[["date", "province", "temperature", "humidity", "season"]],
    on=["date", "province"],
    how="left",
)

display(df_features)
# Out:
# Train-test split date: 2017-10-01 00:00:00
# Training df_features: 175725 rows
# Test df_features: 25300 rows
#              date          province  store_id         store_name  \
# 0      2016-01-01             Hanoi         1   Hoan Kiem Market
# 1      2016-01-01             Hanoi         1   Hoan Kiem Market
# 2      2016-01-01             Hanoi         1   Hoan Kiem Market
# 3      2016-01-01             Hanoi         1   Hoan Kiem Market
# 4      2016-01-01             Hanoi         1   Hoan Kiem Market
# ...           ...               ...       ...                ...
# 201020 2017-12-31  Ho Chi Minh City        10  Binh Thanh Market
# 201021 2017-12-31  Ho Chi Minh City        10  Binh Thanh Market
# 201022 2017-12-31  Ho Chi Minh City        10  Binh Thanh Market
# 201023 2017-12-31  Ho Chi Minh City        10  Binh Thanh Market
# 201024 2017-12-31  Ho Chi Minh City        10  Binh Thanh Market
#
#              category  item_id            item_name  sales  is_test  \
# 0             Staples        1                 Rice   15.0    False
# 1             Staples        2              Noodles   12.0    False
# 2             Staples        3                Bread   15.0    False
# 3             Staples        4                Flour    7.0    False
# 4             Staples        5          Cooking Oil    9.0    False
# ...               ...      ...                  ...    ...      ...
# 201020  Baby & Health       31           Baby Wipes   33.0     True
# 201021  Baby & Health       32       Pain Relievers   22.0     True
# 201022  Baby & Health       33             Vitamins   16.0     True
# 201023  Baby & Health       34  Cold & Flu Medicine   13.0     True
# 201024  Baby & Health       35        First Aid Kit   11.0     True
#
#         temperature  humidity  season
# 0              13.4      87.8  winter
# 1              13.4      87.8  winter
# 2              13.4      87.8  winter
# 3              13.4      87.8  winter
# 4              13.4      87.8  winter
# ...             ...       ...     ...
# 201020         25.9      67.7     dry
# 201021         25.9      67.7     dry
# 201022         25.9      67.7     dry
# 201023         25.9      67.7     dry
# 201024         25.9      67.7     dry
#
# [201025 rows x 12 columns]

# %% [markdown]
# ### Add date and holidays related features

# %%
# Date features
df_features["year"] = df_features["date"].dt.year
df_features["month"] = df_features["date"].dt.month
df_features["day"] = df_features["date"].dt.day
df_features["day_of_week"] = df_features["date"].dt.dayofweek
df_features["is_weekend"] = df_features["day_of_week"].apply(
    lambda x: 1 if x >= 5 else 0
)
df_features["quarter"] = df_features["date"].dt.quarter

# For simplicity in this PoC, we'll consider some major holidays
# In a real scenario, you would have a more comprehensive list based on the specific market
holidays = [
    # Example Vietnamese holidays (simplification)
    "2016-01-01",
    "2016-01-02",
    "2016-01-03",  # New Year
    "2016-04-16",
    "2016-04-17",
    "2016-04-18",  # Hung Kings Festival
    "2016-04-30",
    "2016-05-01",
    "2016-05-02",  # Reunification Day and May Day
    "2016-09-02",
    "2016-09-03",
    "2016-09-04",  # National Day
    "2017-01-01",
    "2017-01-02",  # New Year
    # Add more holidays as needed
]
holidays = pd.to_datetime(holidays)
df_features["is_holiday"] = df_features["date"].isin(holidays).astype(int)

df_features.head()
# Out:
#         date province  store_id        store_name category  item_id  \
# 0 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        1
# 1 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        2
# 2 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        3
# 3 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        4
# 4 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        5
#
#      item_name  sales  is_test  temperature  humidity  season  year  month  \
# 0         Rice   15.0    False         13.4      87.8  winter  2016      1
# 1      Noodles   12.0    False         13.4      87.8  winter  2016      1
# 2        Bread   15.0    False         13.4      87.8  winter  2016      1
# 3        Flour    7.0    False         13.4      87.8  winter  2016      1
# 4  Cooking Oil    9.0    False         13.4      87.8  winter  2016      1
#
#    day  day_of_week  is_weekend  quarter  is_holiday
# 0    1            4           0        1           1
# 1    1            4           0        1           1
# 2    1            4           0        1           1
# 3    1            4           0        1           1
# 4    1            4           0        1           1

# %% [markdown]
# ### Weather-based features

# %%
# Temperature categories (using quantiles for even distribution)
temp_bins = [-np.inf, 20, 25, 30, np.inf]
temp_labels = ["Cold", "Cool", "Warm", "Hot"]
df_features["temp_category"] = pd.cut(
    df_features["temperature"], bins=temp_bins, labels=temp_labels
)

df_features.head()
# Out:
#         date province  store_id        store_name category  item_id  \
# 0 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        1
# 1 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        2
# 2 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        3
# 3 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        4
# 4 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        5
#
#      item_name  sales  is_test  temperature  humidity  season  year  month  \
# 0         Rice   15.0    False         13.4      87.8  winter  2016      1
# 1      Noodles   12.0    False         13.4      87.8  winter  2016      1
# 2        Bread   15.0    False         13.4      87.8  winter  2016      1
# 3        Flour    7.0    False         13.4      87.8  winter  2016      1
# 4  Cooking Oil    9.0    False         13.4      87.8  winter  2016      1
#
#    day  day_of_week  is_weekend  quarter  is_holiday temp_category
# 0    1            4           0        1           1          Cold
# 1    1            4           0        1           1          Cold
# 2    1            4           0        1           1          Cold
# 3    1            4           0        1           1          Cold
# 4    1            4           0        1           1          Cold

# %%
# Humidity levels
humidity_bins = [-np.inf, 60, 75, np.inf]
humidity_labels = ["Low", "Medium", "High"]
df_features["humidity_level"] = pd.cut(
    df_features["humidity"], bins=humidity_bins, labels=humidity_labels
)

df_features.head()
# Out:
#         date province  store_id        store_name category  item_id  \
# 0 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        1
# 1 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        2
# 2 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        3
# 3 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        4
# 4 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        5
#
#      item_name  sales  is_test  temperature  humidity  season  year  month  \
# 0         Rice   15.0    False         13.4      87.8  winter  2016      1
# 1      Noodles   12.0    False         13.4      87.8  winter  2016      1
# 2        Bread   15.0    False         13.4      87.8  winter  2016      1
# 3        Flour    7.0    False         13.4      87.8  winter  2016      1
# 4  Cooking Oil    9.0    False         13.4      87.8  winter  2016      1
#
#    day  day_of_week  is_weekend  quarter  is_holiday temp_category  \
# 0    1            4           0        1           1          Cold
# 1    1            4           0        1           1          Cold
# 2    1            4           0        1           1          Cold
# 3    1            4           0        1           1          Cold
# 4    1            4           0        1           1          Cold
#
#   humidity_level
# 0           High
# 1           High
# 2           High
# 3           High
# 4           High

# %%
# Convert categorical variables to numeric
df_features = pd.get_dummies(
    df_features, columns=["temp_category", "humidity_level", "season"], drop_first=True
)

df_features.head()
# Out:
#         date province  store_id        store_name category  item_id  \
# 0 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        1
# 1 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        2
# 2 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        3
# 3 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        4
# 4 2016-01-01    Hanoi         1  Hoan Kiem Market  Staples        5
#
#      item_name  sales  is_test  temperature  humidity  year  month  day  \
# 0         Rice   15.0    False         13.4      87.8  2016      1    1
# 1      Noodles   12.0    False         13.4      87.8  2016      1    1
# 2        Bread   15.0    False         13.4      87.8  2016      1    1
# 3        Flour    7.0    False         13.4      87.8  2016      1    1
# 4  Cooking Oil    9.0    False         13.4      87.8  2016      1    1
#
#    day_of_week  is_weekend  quarter  is_holiday  temp_category_Cool  \
# 0            4           0        1           1               False
# 1            4           0        1           1               False
# 2            4           0        1           1               False
# 3            4           0        1           1               False
# 4            4           0        1           1               False
#
#    temp_category_Warm  temp_category_Hot  humidity_level_Medium  \
# 0               False              False                  False
# 1               False              False                  False
# 2               False              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    humidity_level_High  season_fall  season_spring  season_summer  season_wet  \
# 0                 True        False          False          False       False
# 1                 True        False          False          False       False
# 2                 True        False          False          False       False
# 3                 True        False          False          False       False
# 4                 True        False          False          False       False
#
#    season_winter
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %% [markdown]
# ### Last n days sales

# %%
# Sort df_features by date, store, and item for proper lag feature creation
df_features = df_features.sort_values(["date", "store_name", "item_name"])

# Create an identifier for store-item combinations for grouping
df_features["store_item"] = df_features["store_name"] + "_" + df_features["item_name"]

# %%
# Create lag features for sales - last n days
for n in [1, 7, 14, 28]:
    # Group by store_item and create lag features
    df_features[f"sales_lag_{n}"] = df_features.groupby("store_item")[
        "sales"
    ].transform(lambda x: x.shift(n))

# %% [markdown]
# ### Rolling average features

# %%
# Create rolling average features
for window in [7, 14, 28]:
    # Mean of last n days
    df_features[f"sales_mean_{window}d"] = df_features.groupby("store_item")[
        "sales"
    ].transform(lambda x: x.shift(1).rolling(window=window, min_periods=1).mean())

    # Min of last n days
    df_features[f"sales_min_{window}d"] = df_features.groupby("store_item")[
        "sales"
    ].transform(lambda x: x.shift(1).rolling(window=window, min_periods=1).min())

    # Max of last n days
    df_features[f"sales_max_{window}d"] = df_features.groupby("store_item")[
        "sales"
    ].transform(lambda x: x.shift(1).rolling(window=window, min_periods=1).max())

    # Standard deviation of last n days
    df_features[f"sales_std_{window}d"] = df_features.groupby("store_item")[
        "sales"
    ].transform(lambda x: x.shift(1).rolling(window=window, min_periods=1).std())

# %%
df_features.query("store_item == 'Ba Dinh Supermarket_Baby Wipes'")
# .to_csv("../data/check_data_01.csv", index=False)
# Out:
#              date province  store_id           store_name       category  \
# 53     2016-01-01    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 328    2016-01-02    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 603    2016-01-03    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 878    2016-01-04    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 1153   2016-01-05    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# ...           ...      ...       ...                  ...            ...
# 199703 2017-12-27    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 199978 2017-12-28    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200253 2017-12-29    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200528 2017-12-30    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200803 2017-12-31    Hanoi         2  Ba Dinh Supermarket  Baby & Health
#
#         item_id   item_name  sales  is_test  temperature  humidity  year  \
# 53           31  Baby Wipes   22.0    False         13.4      87.8  2016
# 328          31  Baby Wipes   31.0    False         15.2      75.2  2016
# 603          31  Baby Wipes   25.0    False         19.2      86.0  2016
# 878          31  Baby Wipes   29.0    False         12.8      85.4  2016
# 1153         31  Baby Wipes   22.0    False         16.8      88.3  2016
# ...         ...         ...    ...      ...          ...       ...   ...
# 199703       31  Baby Wipes   37.0     True         20.0      79.9  2017
# 199978       31  Baby Wipes   45.0     True         17.2      67.2  2017
# 200253       31  Baby Wipes   40.0     True         21.0      76.1  2017
# 200528       31  Baby Wipes   56.0     True         20.9      80.8  2017
# 200803       31  Baby Wipes   62.0     True         15.3      70.7  2017
#
#         month  day  day_of_week  is_weekend  quarter  is_holiday  \
# 53          1    1            4           0        1           1
# 328         1    2            5           1        1           1
# 603         1    3            6           1        1           1
# 878         1    4            0           0        1           0
# 1153        1    5            1           0        1           0
# ...       ...  ...          ...         ...      ...         ...
# 199703     12   27            2           0        4           0
# 199978     12   28            3           0        4           0
# 200253     12   29            4           0        4           0
# 200528     12   30            5           1        4           0
# 200803     12   31            6           1        4           0
#
#         temp_category_Cool  temp_category_Warm  temp_category_Hot  \
# 53                   False               False              False
# 328                  False               False              False
# 603                  False               False              False
# 878                  False               False              False
# 1153                 False               False              False
# ...                    ...                 ...                ...
# 199703               False               False              False
# 199978               False               False              False
# 200253                True               False              False
# 200528                True               False              False
# 200803               False               False              False
#
#         humidity_level_Medium  humidity_level_High  season_fall  \
# 53                      False                 True        False
# 328                     False                 True        False
# 603                     False                 True        False
# 878                     False                 True        False
# 1153                    False                 True        False
# ...                       ...                  ...          ...
# 199703                  False                 True        False
# 199978                   True                False        False
# 200253                  False                 True        False
# 200528                  False                 True        False
# 200803                   True                False        False
#
#         season_spring  season_summer  season_wet  season_winter  \
# 53              False          False       False           True
# 328             False          False       False           True
# 603             False          False       False           True
# 878             False          False       False           True
# 1153            False          False       False           True
# ...               ...            ...         ...            ...
# 199703          False          False       False           True
# 199978          False          False       False           True
# 200253          False          False       False           True
# 200528          False          False       False           True
# 200803          False          False       False           True
#
#                             store_item  sales_lag_1  sales_lag_7  \
# 53      Ba Dinh Supermarket_Baby Wipes          NaN          NaN
# 328     Ba Dinh Supermarket_Baby Wipes         22.0          NaN
# 603     Ba Dinh Supermarket_Baby Wipes         31.0          NaN
# 878     Ba Dinh Supermarket_Baby Wipes         25.0          NaN
# 1153    Ba Dinh Supermarket_Baby Wipes         29.0          NaN
# ...                                ...          ...          ...
# 199703  Ba Dinh Supermarket_Baby Wipes         34.0         42.0
# 199978  Ba Dinh Supermarket_Baby Wipes         37.0         29.0
# 200253  Ba Dinh Supermarket_Baby Wipes         45.0         37.0
# 200528  Ba Dinh Supermarket_Baby Wipes         40.0         52.0
# 200803  Ba Dinh Supermarket_Baby Wipes         56.0         84.0
#
#         sales_lag_14  sales_lag_28  sales_mean_7d  sales_min_7d  sales_max_7d  \
# 53               NaN           NaN            NaN           NaN           NaN
# 328              NaN           NaN      22.000000          22.0          22.0
# 603              NaN           NaN      26.500000          22.0          31.0
# 878              NaN           NaN      26.000000          22.0          31.0
# 1153             NaN           NaN      26.750000          22.0          31.0
# ...              ...           ...            ...           ...           ...
# 199703          38.0          23.0      45.857143          29.0          84.0
# 199978          26.0          25.0      45.142857          29.0          84.0
# 200253          19.0          27.0      47.428571          34.0          84.0
# 200528          45.0          33.0      47.857143          34.0          84.0
# 200803          40.0          48.0      48.428571          34.0          84.0
#
#         sales_std_7d  sales_mean_14d  sales_min_14d  sales_max_14d  \
# 53               NaN             NaN            NaN            NaN
# 328              NaN       22.000000           22.0           22.0
# 603         6.363961       26.500000           22.0           31.0
# 878         4.582576       26.000000           22.0           31.0
# 1153        4.031129       26.750000           22.0           31.0
# ...              ...             ...            ...            ...
# 199703     18.343287       39.142857           19.0           84.0
# 199978     18.613871       39.071429           19.0           84.0
# 200253     17.232306       40.428571           19.0           84.0
# 200528     16.964950       41.928571           29.0           84.0
# 200803     17.193576       42.714286           29.0           84.0
#
#         sales_std_14d  sales_mean_28d  sales_min_28d  sales_max_28d  \
# 53                NaN             NaN            NaN            NaN
# 328               NaN       22.000000           22.0           22.0
# 603          6.363961       26.500000           22.0           31.0
# 878          4.582576       26.000000           22.0           31.0
# 1153         4.031129       26.750000           22.0           31.0
# ...               ...             ...            ...            ...
# 199703      15.530898       35.857143           18.0           84.0
# 199978      15.538856       36.357143           18.0           84.0
# 200253      15.133835       37.071429           18.0           84.0
# 200528      13.831204       37.535714           18.0           84.0
# 200803      14.322809       38.357143           18.0           84.0
#
#         sales_std_28d
# 53                NaN
# 328               NaN
# 603          6.363961
# 878          4.582576
# 1153         4.031129
# ...               ...
# 199703      12.903385
# 199978      12.655592
# 200253      12.554853
# 200528      12.408128
# 200803      12.850174
#
# [731 rows x 45 columns]

# %% [markdown]
# ### Exponentially weighted moving average

# %%
# Exponentially weighted moving average
for alpha in [0.5, 0.75]:
    for window in [7, 14, 28]:
        # Create an EWMA feature
        alpha_str = str(alpha).replace(".", "")
        df_features[f"sales_ewma_{window}d_a{alpha_str}"] = df_features.groupby(
            "store_item"
        )["sales"].transform(lambda x: x.shift(1).ewm(alpha=alpha).mean())

# %%
df_features.query("store_item == 'Ba Dinh Supermarket_Baby Wipes'")
# Out:
#              date province  store_id           store_name       category  \
# 53     2016-01-01    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 328    2016-01-02    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 603    2016-01-03    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 878    2016-01-04    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 1153   2016-01-05    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# ...           ...      ...       ...                  ...            ...
# 199703 2017-12-27    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 199978 2017-12-28    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200253 2017-12-29    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200528 2017-12-30    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200803 2017-12-31    Hanoi         2  Ba Dinh Supermarket  Baby & Health
#
#         item_id   item_name  sales  is_test  temperature  humidity  year  \
# 53           31  Baby Wipes   22.0    False         13.4      87.8  2016
# 328          31  Baby Wipes   31.0    False         15.2      75.2  2016
# 603          31  Baby Wipes   25.0    False         19.2      86.0  2016
# 878          31  Baby Wipes   29.0    False         12.8      85.4  2016
# 1153         31  Baby Wipes   22.0    False         16.8      88.3  2016
# ...         ...         ...    ...      ...          ...       ...   ...
# 199703       31  Baby Wipes   37.0     True         20.0      79.9  2017
# 199978       31  Baby Wipes   45.0     True         17.2      67.2  2017
# 200253       31  Baby Wipes   40.0     True         21.0      76.1  2017
# 200528       31  Baby Wipes   56.0     True         20.9      80.8  2017
# 200803       31  Baby Wipes   62.0     True         15.3      70.7  2017
#
#         month  day  day_of_week  is_weekend  quarter  is_holiday  \
# 53          1    1            4           0        1           1
# 328         1    2            5           1        1           1
# 603         1    3            6           1        1           1
# 878         1    4            0           0        1           0
# 1153        1    5            1           0        1           0
# ...       ...  ...          ...         ...      ...         ...
# 199703     12   27            2           0        4           0
# 199978     12   28            3           0        4           0
# 200253     12   29            4           0        4           0
# 200528     12   30            5           1        4           0
# 200803     12   31            6           1        4           0
#
#         temp_category_Cool  temp_category_Warm  temp_category_Hot  \
# 53                   False               False              False
# 328                  False               False              False
# 603                  False               False              False
# 878                  False               False              False
# 1153                 False               False              False
# ...                    ...                 ...                ...
# 199703               False               False              False
# 199978               False               False              False
# 200253                True               False              False
# 200528                True               False              False
# 200803               False               False              False
#
#         humidity_level_Medium  humidity_level_High  season_fall  \
# 53                      False                 True        False
# 328                     False                 True        False
# 603                     False                 True        False
# 878                     False                 True        False
# 1153                    False                 True        False
# ...                       ...                  ...          ...
# 199703                  False                 True        False
# 199978                   True                False        False
# 200253                  False                 True        False
# 200528                  False                 True        False
# 200803                   True                False        False
#
#         season_spring  season_summer  season_wet  season_winter  \
# 53              False          False       False           True
# 328             False          False       False           True
# 603             False          False       False           True
# 878             False          False       False           True
# 1153            False          False       False           True
# ...               ...            ...         ...            ...
# 199703          False          False       False           True
# 199978          False          False       False           True
# 200253          False          False       False           True
# 200528          False          False       False           True
# 200803          False          False       False           True
#
#                             store_item  sales_lag_1  sales_lag_7  \
# 53      Ba Dinh Supermarket_Baby Wipes          NaN          NaN
# 328     Ba Dinh Supermarket_Baby Wipes         22.0          NaN
# 603     Ba Dinh Supermarket_Baby Wipes         31.0          NaN
# 878     Ba Dinh Supermarket_Baby Wipes         25.0          NaN
# 1153    Ba Dinh Supermarket_Baby Wipes         29.0          NaN
# ...                                ...          ...          ...
# 199703  Ba Dinh Supermarket_Baby Wipes         34.0         42.0
# 199978  Ba Dinh Supermarket_Baby Wipes         37.0         29.0
# 200253  Ba Dinh Supermarket_Baby Wipes         45.0         37.0
# 200528  Ba Dinh Supermarket_Baby Wipes         40.0         52.0
# 200803  Ba Dinh Supermarket_Baby Wipes         56.0         84.0
#
#         sales_lag_14  sales_lag_28  sales_mean_7d  sales_min_7d  sales_max_7d  \
# 53               NaN           NaN            NaN           NaN           NaN
# 328              NaN           NaN      22.000000          22.0          22.0
# 603              NaN           NaN      26.500000          22.0          31.0
# 878              NaN           NaN      26.000000          22.0          31.0
# 1153             NaN           NaN      26.750000          22.0          31.0
# ...              ...           ...            ...           ...           ...
# 199703          38.0          23.0      45.857143          29.0          84.0
# 199978          26.0          25.0      45.142857          29.0          84.0
# 200253          19.0          27.0      47.428571          34.0          84.0
# 200528          45.0          33.0      47.857143          34.0          84.0
# 200803          40.0          48.0      48.428571          34.0          84.0
#
#         sales_std_7d  sales_mean_14d  sales_min_14d  sales_max_14d  \
# 53               NaN             NaN            NaN            NaN
# 328              NaN       22.000000           22.0           22.0
# 603         6.363961       26.500000           22.0           31.0
# 878         4.582576       26.000000           22.0           31.0
# 1153        4.031129       26.750000           22.0           31.0
# ...              ...             ...            ...            ...
# 199703     18.343287       39.142857           19.0           84.0
# 199978     18.613871       39.071429           19.0           84.0
# 200253     17.232306       40.428571           19.0           84.0
# 200528     16.964950       41.928571           29.0           84.0
# 200803     17.193576       42.714286           29.0           84.0
#
#         sales_std_14d  sales_mean_28d  sales_min_28d  sales_max_28d  \
# 53                NaN             NaN            NaN            NaN
# 328               NaN       22.000000           22.0           22.0
# 603          6.363961       26.500000           22.0           31.0
# 878          4.582576       26.000000           22.0           31.0
# 1153         4.031129       26.750000           22.0           31.0
# ...               ...             ...            ...            ...
# 199703      15.530898       35.857143           18.0           84.0
# 199978      15.538856       36.357143           18.0           84.0
# 200253      15.133835       37.071429           18.0           84.0
# 200528      13.831204       37.535714           18.0           84.0
# 200803      14.322809       38.357143           18.0           84.0
#
#         sales_std_28d  sales_ewma_7d_a05  sales_ewma_14d_a05  \
# 53                NaN                NaN                 NaN
# 328               NaN          22.000000           22.000000
# 603          6.363961          28.000000           28.000000
# 878          4.582576          26.285714           26.285714
# 1153         4.031129          27.733333           27.733333
# ...               ...                ...                 ...
# 199703      12.903385          43.682192           43.682192
# 199978      12.655592          40.341096           40.341096
# 200253      12.554853          42.670548           42.670548
# 200528      12.408128          41.335274           41.335274
# 200803      12.850174          48.667637           48.667637
#
#         sales_ewma_28d_a05  sales_ewma_7d_a075  sales_ewma_14d_a075  \
# 53                     NaN                 NaN                  NaN
# 328              22.000000           22.000000            22.000000
# 603              28.000000           29.200000            29.200000
# 878              26.285714           26.000000            26.000000
# 1153             27.733333           28.258824            28.258824
# ...                    ...                 ...                  ...
# 199703           43.682192           38.248527            38.248527
# 199978           40.341096           37.312132            37.312132
# 200253           42.670548           43.078033            43.078033
# 200528           41.335274           40.769508            40.769508
# 200803           48.667637           52.192377            52.192377
#
#         sales_ewma_28d_a075
# 53                      NaN
# 328               22.000000
# 603               29.200000
# 878               26.000000
# 1153              28.258824
# ...                     ...
# 199703            38.248527
# 199978            37.312132
# 200253            43.078033
# 200528            40.769508
# 200803            52.192377
#
# [731 rows x 51 columns]

# %% [markdown]
# ### Store-level features

# %%
# Mean and sum of store sales in the last 7 days
df_features["store_mean_7d"] = df_features.groupby(["store_name", "date"])[
    "sales"
].transform("mean")
df_features["store_sum_7d"] = df_features.groupby(["store_name", "date"])[
    "sales"
].transform("sum")

# %% [markdown]
# ### Item-level features

# %%
# Mean and sum of item sales in the last 7 days
df_features["item_mean_7d"] = df_features.groupby(["item_name", "date"])[
    "sales"
].transform("mean")
df_features["item_sum_7d"] = df_features.groupby(["item_name", "date"])[
    "sales"
].transform("sum")

# %%
df_features.query("store_item == 'Ba Dinh Supermarket_Baby Wipes'")
# Out:
#              date province  store_id           store_name       category  \
# 53     2016-01-01    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 328    2016-01-02    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 603    2016-01-03    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 878    2016-01-04    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 1153   2016-01-05    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# ...           ...      ...       ...                  ...            ...
# 199703 2017-12-27    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 199978 2017-12-28    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200253 2017-12-29    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200528 2017-12-30    Hanoi         2  Ba Dinh Supermarket  Baby & Health
# 200803 2017-12-31    Hanoi         2  Ba Dinh Supermarket  Baby & Health
#
#         item_id   item_name  sales  is_test  temperature  humidity  year  \
# 53           31  Baby Wipes   22.0    False         13.4      87.8  2016
# 328          31  Baby Wipes   31.0    False         15.2      75.2  2016
# 603          31  Baby Wipes   25.0    False         19.2      86.0  2016
# 878          31  Baby Wipes   29.0    False         12.8      85.4  2016
# 1153         31  Baby Wipes   22.0    False         16.8      88.3  2016
# ...         ...         ...    ...      ...          ...       ...   ...
# 199703       31  Baby Wipes   37.0     True         20.0      79.9  2017
# 199978       31  Baby Wipes   45.0     True         17.2      67.2  2017
# 200253       31  Baby Wipes   40.0     True         21.0      76.1  2017
# 200528       31  Baby Wipes   56.0     True         20.9      80.8  2017
# 200803       31  Baby Wipes   62.0     True         15.3      70.7  2017
#
#         month  day  day_of_week  is_weekend  quarter  is_holiday  \
# 53          1    1            4           0        1           1
# 328         1    2            5           1        1           1
# 603         1    3            6           1        1           1
# 878         1    4            0           0        1           0
# 1153        1    5            1           0        1           0
# ...       ...  ...          ...         ...      ...         ...
# 199703     12   27            2           0        4           0
# 199978     12   28            3           0        4           0
# 200253     12   29            4           0        4           0
# 200528     12   30            5           1        4           0
# 200803     12   31            6           1        4           0
#
#         temp_category_Cool  temp_category_Warm  temp_category_Hot  \
# 53                   False               False              False
# 328                  False               False              False
# 603                  False               False              False
# 878                  False               False              False
# 1153                 False               False              False
# ...                    ...                 ...                ...
# 199703               False               False              False
# 199978               False               False              False
# 200253                True               False              False
# 200528                True               False              False
# 200803               False               False              False
#
#         humidity_level_Medium  humidity_level_High  season_fall  \
# 53                      False                 True        False
# 328                     False                 True        False
# 603                     False                 True        False
# 878                     False                 True        False
# 1153                    False                 True        False
# ...                       ...                  ...          ...
# 199703                  False                 True        False
# 199978                   True                False        False
# 200253                  False                 True        False
# 200528                  False                 True        False
# 200803                   True                False        False
#
#         season_spring  season_summer  season_wet  season_winter  \
# 53              False          False       False           True
# 328             False          False       False           True
# 603             False          False       False           True
# 878             False          False       False           True
# 1153            False          False       False           True
# ...               ...            ...         ...            ...
# 199703          False          False       False           True
# 199978          False          False       False           True
# 200253          False          False       False           True
# 200528          False          False       False           True
# 200803          False          False       False           True
#
#                             store_item  sales_lag_1  sales_lag_7  \
# 53      Ba Dinh Supermarket_Baby Wipes          NaN          NaN
# 328     Ba Dinh Supermarket_Baby Wipes         22.0          NaN
# 603     Ba Dinh Supermarket_Baby Wipes         31.0          NaN
# 878     Ba Dinh Supermarket_Baby Wipes         25.0          NaN
# 1153    Ba Dinh Supermarket_Baby Wipes         29.0          NaN
# ...                                ...          ...          ...
# 199703  Ba Dinh Supermarket_Baby Wipes         34.0         42.0
# 199978  Ba Dinh Supermarket_Baby Wipes         37.0         29.0
# 200253  Ba Dinh Supermarket_Baby Wipes         45.0         37.0
# 200528  Ba Dinh Supermarket_Baby Wipes         40.0         52.0
# 200803  Ba Dinh Supermarket_Baby Wipes         56.0         84.0
#
#         sales_lag_14  sales_lag_28  sales_mean_7d  sales_min_7d  sales_max_7d  \
# 53               NaN           NaN            NaN           NaN           NaN
# 328              NaN           NaN      22.000000          22.0          22.0
# 603              NaN           NaN      26.500000          22.0          31.0
# 878              NaN           NaN      26.000000          22.0          31.0
# 1153             NaN           NaN      26.750000          22.0          31.0
# ...              ...           ...            ...           ...           ...
# 199703          38.0          23.0      45.857143          29.0          84.0
# 199978          26.0          25.0      45.142857          29.0          84.0
# 200253          19.0          27.0      47.428571          34.0          84.0
# 200528          45.0          33.0      47.857143          34.0          84.0
# 200803          40.0          48.0      48.428571          34.0          84.0
#
#         sales_std_7d  sales_mean_14d  sales_min_14d  sales_max_14d  \
# 53               NaN             NaN            NaN            NaN
# 328              NaN       22.000000           22.0           22.0
# 603         6.363961       26.500000           22.0           31.0
# 878         4.582576       26.000000           22.0           31.0
# 1153        4.031129       26.750000           22.0           31.0
# ...              ...             ...            ...            ...
# 199703     18.343287       39.142857           19.0           84.0
# 199978     18.613871       39.071429           19.0           84.0
# 200253     17.232306       40.428571           19.0           84.0
# 200528     16.964950       41.928571           29.0           84.0
# 200803     17.193576       42.714286           29.0           84.0
#
#         sales_std_14d  sales_mean_28d  sales_min_28d  sales_max_28d  \
# 53                NaN             NaN            NaN            NaN
# 328               NaN       22.000000           22.0           22.0
# 603          6.363961       26.500000           22.0           31.0
# 878          4.582576       26.000000           22.0           31.0
# 1153         4.031129       26.750000           22.0           31.0
# ...               ...             ...            ...            ...
# 199703      15.530898       35.857143           18.0           84.0
# 199978      15.538856       36.357143           18.0           84.0
# 200253      15.133835       37.071429           18.0           84.0
# 200528      13.831204       37.535714           18.0           84.0
# 200803      14.322809       38.357143           18.0           84.0
#
#         sales_std_28d  sales_ewma_7d_a05  sales_ewma_14d_a05  \
# 53                NaN                NaN                 NaN
# 328               NaN          22.000000           22.000000
# 603          6.363961          28.000000           28.000000
# 878          4.582576          26.285714           26.285714
# 1153         4.031129          27.733333           27.733333
# ...               ...                ...                 ...
# 199703      12.903385          43.682192           43.682192
# 199978      12.655592          40.341096           40.341096
# 200253      12.554853          42.670548           42.670548
# 200528      12.408128          41.335274           41.335274
# 200803      12.850174          48.667637           48.667637
#
#         sales_ewma_28d_a05  sales_ewma_7d_a075  sales_ewma_14d_a075  \
# 53                     NaN                 NaN                  NaN
# 328              22.000000           22.000000            22.000000
# 603              28.000000           29.200000            29.200000
# 878              26.285714           26.000000            26.000000
# 1153             27.733333           28.258824            28.258824
# ...                    ...                 ...                  ...
# 199703           43.682192           38.248527            38.248527
# 199978           40.341096           37.312132            37.312132
# 200253           42.670548           43.078033            43.078033
# 200528           41.335274           40.769508            40.769508
# 200803           48.667637           52.192377            52.192377
#
#         sales_ewma_28d_a075  store_mean_7d  store_sum_7d  item_mean_7d  \
# 53                      NaN      17.607143    493.000000     26.833333
# 328               22.000000      19.428571    544.000000     34.333333
# 603               29.200000      24.964286    699.000000     27.666667
# 878               26.000000      18.051497    505.441919     27.666667
# 1153              28.258824      18.214286    510.000000     24.166667
# ...                     ...            ...           ...           ...
# 199703            38.248527      37.071429   1038.000000     60.333333
# 199978            37.312132      34.515783    966.441919     62.333333
# 200253            43.078033      33.837211    947.441919     51.166667
# 200528            40.769508      41.670274   1166.767677     64.666667
# 200803            52.192377      40.872926   1144.441919     59.666667
#
#         item_sum_7d
# 53            161.0
# 328           206.0
# 603           166.0
# 878           166.0
# 1153          145.0
# ...             ...
# 199703        362.0
# 199978        374.0
# 200253        307.0
# 200528        388.0
# 200803        358.0
#
# [731 rows x 55 columns]

# %%
# Drop rows with NaN (these will be the first n days without lag features)
df_features = df_features.dropna()

# %% [markdown]
# ## Save feature engineered data

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193325 entries, 7752 to 200845
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   193325 non-null  datetime64[ns]
#  1   province               193325 non-null  object
#  2   store_id               193325 non-null  int64
#  3   store_name             193325 non-null  object
#  4   category               193325 non-null  object
#  5   item_id                193325 non-null  int64
#  6   item_name              193325 non-null  object
#  7   sales                  193325 non-null  float64
#  8   is_test                193325 non-null  bool
#  9   temperature            193325 non-null  float64
#  10  humidity               193325 non-null  float64
#  11  year                   193325 non-null  int32
#  12  month                  193325 non-null  int32
#  13  day                    193325 non-null  int32
#  14  day_of_week            193325 non-null  int32
#  15  is_weekend             193325 non-null  int64
#  16  quarter                193325 non-null  int32
#  17  is_holiday             193325 non-null  int64
#  18  temp_category_Cool     193325 non-null  bool
#  19  temp_category_Warm     193325 non-null  bool
#  20  temp_category_Hot      193325 non-null  bool
#  21  humidity_level_Medium  193325 non-null  bool
#  22  humidity_level_High    193325 non-null  bool
#  23  season_fall            193325 non-null  bool
#  24  season_spring          193325 non-null  bool
#  25  season_summer          193325 non-null  bool
#  26  season_wet             193325 non-null  bool
#  27  season_winter          193325 non-null  bool
#  28  store_item             193325 non-null  object
#  29  sales_lag_1            193325 non-null  float64
#  30  sales_lag_7            193325 non-null  float64
#  31  sales_lag_14           193325 non-null  float64
#  32  sales_lag_28           193325 non-null  float64
#  33  sales_mean_7d          193325 non-null  float64
#  34  sales_min_7d           193325 non-null  float64
#  35  sales_max_7d           193325 non-null  float64
#  36  sales_std_7d           193325 non-null  float64
#  37  sales_mean_14d         193325 non-null  float64
#  38  sales_min_14d          193325 non-null  float64
#  39  sales_max_14d          193325 non-null  float64
#  40  sales_std_14d          193325 non-null  float64
#  41  sales_mean_28d         193325 non-null  float64
#  42  sales_min_28d          193325 non-null  float64
#  43  sales_max_28d          193325 non-null  float64
#  44  sales_std_28d          193325 non-null  float64
#  45  sales_ewma_7d_a05      193325 non-null  float64
#  46  sales_ewma_14d_a05     193325 non-null  float64
#  47  sales_ewma_28d_a05     193325 non-null  float64
#  48  sales_ewma_7d_a075     193325 non-null  float64
#  49  sales_ewma_14d_a075    193325 non-null  float64
#  50  sales_ewma_28d_a075    193325 non-null  float64
#  51  store_mean_7d          193325 non-null  float64
#  52  store_sum_7d           193325 non-null  float64
#  53  item_mean_7d           193325 non-null  float64
#  54  item_sum_7d            193325 non-null  float64
# dtypes: bool(11), datetime64[ns](1), float64(29), int32(5), int64(4), object(5)
# memory usage: 64.7+ MB

# %%
# PATH
num_features = df_features.shape[1]
save_path = os.path.join(DATA_DIR, f"feature_engineered_data_{num_features}_features.feather")
save_path
# Out:
# '../data\\feature_engineered_data_55_features.feather'

# %%
# Save data
save_data(df_features, save_path, file_format='feather')
# Out:
# DataFrame saved to ../data\feature_engineered_data_55_features.feather in Feather format.
